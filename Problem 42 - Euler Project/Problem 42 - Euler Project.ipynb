# %%
def char_number(char: str):
    return (ord(char.upper()) - ord("A") + 1)

# %%
with open(r"words.txt", "r") as file:
    content = file.read()
    print(type(content))
# Out:
# <class 'str'>

# %%
for i in range(10):
    
    print(content[i])
# Out:
# "
# A
# "
# ,
# "
# A
# B
# I
# L
# I
