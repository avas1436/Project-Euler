# %% [markdown]
# This is the best problem i ever solved :))))

# %%
def answer(leng: int) -> int:    
    a, b = 1, 1
    index = 2
    while True:
        a, b = b, a+b
        index += 1
        if len(str(b)) == leng:
            return index

# %%
answer(1000)
# Out:
# 4782
