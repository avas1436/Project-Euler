# %%
def is_prime(num: int):
    if num < 2:
        return False
    if num == 2:
        return True
    if num % 2 == 0:
        return False
    i = 3
    while i * i <= num:
        if num % i == 0:
            return False
        i += 2
    return True

# %%
def rotator(num: int):
    str_num = str(num)
    i = len(str_num) 
    for j in range(i):
        print(str_num[j:] + str_num[:j])
